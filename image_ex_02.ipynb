# %%
import cv2
import numpy as np

# %%
filename = "check.jpg" # harris corner
img = cv2.imread(filename, 0)
# gray = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

gray = np.float32(img)
dst = cv2.cornerHarris(gray,2,3,0.04)
dst = cv2.dilate(dst, None)

# %%
img[dst>0.01*dst.max()]=[0,0,255]

cv2.imshow('dst',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-5a62bce4a081> in <module>()
# ----> 1 img[dst>0.01*dst.max()]=[0,0,255]
#       2
#       3 cv2.imshow('dst',img)
#       4 cv2.waitKey(0)
#       5 cv2.destroyAllWindows()
#
# ValueError: NumPy boolean array indexing assignment cannot assign 3 input values to the 1689 output values where the mask is true

# %%
filename = "taylor.jpg" # criterio
img = cv2.imread(filename)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray, 2, 3, 0.04)
dst = cv2.dilate(dst, None)
ret, dst = cv2.threshold(dst, 0.01*dst.max(), 255, 0)
dst = np.unit8(dst)

# %%
ret, labels, stats, centroids = cv2.connectedComponentsWithStats(dst)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.001)
corners = cv2.cornerSubPix(gray, np.float32(centroids), (5,5), (-1,-1),criteria)

# %%
# res = np.hstack((centroids, corners))
# res = np.int0(res)
# img[res[:,1],res[:,0]]=[0,0,255]
# img[res[:,3],res[:,2]] = [0,255,0]

# cv2.imshow('dst',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

filename = "taylor.jpg"
img = cv2.imread(filename, 0)
#gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

corners = cv2.goodFeaturesToTrack(img, 25, 0.01, 10)
corners = np.int0(corners)

# cv2.imshow('dst',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

for i in corners :
    x,y = i.ravel()
    cv2.circle(img, (x,y), 3, 255, -1)
    
plt.imshow(img),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1e6c1eff048>, None)

# %%
img1 = cv2.imread('taylor.jpg')
img2 = cv2.imread('strawberry.jpg')
rows, cols, channels = img2.shape

img1[300:300+rows, 200:200+cols] = img2

res = cv2.resize(img1, None, fx=0.25, fy=0.25, interpolation = cv2.INTER_CUBIC)

cv2.imshow('resize',res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
canvas = np.zeros((100, 512, 3), np.uint8)
cv2.imshow('canvas', canvas)
cv2.waitKey(0)
cv2.destroyAllWindows()
